# %%
# import semua lib yang diperlukan
import pandas as pd
import numpy as np
from fbprophet import Prophet
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error 
#import requests
#import json
#from types import SimpleNamespace
# from pandas.io.json import json_normalize

# %%
# read file csv
df = pd.read_csv('dataset/cabe rawit merah.csv')
# ambil data dari API Priangan
#r = requests.get('http://dev.priangan.org/api/api/graphic_data/2/1/day/price/2012-01-01/2021-2-15/0/city/-/eceran/null')
#df = r.json()
df
# Out:
#      status  message  data__total  data__result__value data__result__time  \
# 0        ok      NaN   82873079.0                29200    January 3, 2012
# 1       NaN      NaN          NaN                29200    January 4, 2012
# 2       NaN      NaN          NaN                29200    January 5, 2012
# 3       NaN      NaN          NaN                29600    January 6, 2012
# 4       NaN      NaN          NaN                31200    January 7, 2012
# ...     ...      ...          ...                  ...                ...
# 1841    NaN      NaN          NaN                46000      March 2, 2020
# 1842    NaN      NaN          NaN                48000      March 3, 2020
# 1843    NaN      NaN          NaN                39000      March 4, 2020
# 1844    NaN      NaN          NaN                50000      March 5, 2020
# 1845    NaN      NaN          NaN                43000      March 8, 2020
#
#      data__result__date  data__result__span  data__average  data__location_id  \
# 0            2012-01-03                   3        44893.0                1.0
# 1            2012-01-04                   4            NaN                NaN
# 2            2012-01-05                   5            NaN                NaN
# 3            2012-01-06                   6            NaN                NaN
# 4            2012-01-07                   7            NaN                NaN
# ...                 ...                 ...            ...                ...
# 1841         2020-03-02                  62            NaN                NaN
# 1842         2020-03-03                  63            NaN                NaN
# 1843         2020-03-04                  64            NaN                NaN
# 1844         2020-03-05                  65            NaN                NaN
# 1845         2020-03-08                  68            NaN                NaN
#
#       data__commodity_id        data__legend data__commodity_name  \
# 0                   18.0  Harga Kota Bandung     Cabe Rawit Merah
# 1                    NaN                 NaN                  NaN
# 2                    NaN                 NaN                  NaN
# 3                    NaN                 NaN                  NaN
# 4                    NaN                 NaN                  NaN
# ...                  ...                 ...                  ...
# 1841                 NaN                 NaN                  NaN
# 1842                 NaN                 NaN                  NaN
# 1843                 NaN                 NaN                  NaN
# 1844                 NaN                 NaN                  NaN
# 1845                 NaN                 NaN                  NaN
#
#               stat__|  stat__|__total  stat__|__nb_data  stat__|__avg
# 0     January 3, 2012           29200                 1         29200
# 1     January 4, 2012           29200                 1         29200
# 2     January 5, 2012           29200                 1         29200
# 3     January 6, 2012           29600                 1         29600
# 4     January 7, 2012           31200                 1         31200
# ...               ...             ...               ...           ...
# 1841    March 2, 2020           46000                 1         46000
# 1842    March 3, 2020           48000                 1         48000
# 1843    March 4, 2020           39000                 1         39000
# 1844    March 5, 2020           50000                 1         50000
# 1845    March 8, 2020           43000                 1         43000
#
# [1846 rows x 16 columns]

# %%
#data cleaning(hapus data yang tidak terpakai)
df.drop(['status','message','data__total','data__result__time','data__result__span','data__average','data__location_id','data__commodity_id','data__legend','data__commodity_name','stat__|','stat__|__total','stat__|__nb_data','stat__|__avg'], axis=1, inplace=True)
df.head()
# Out:
#    data__result__value data__result__date
# 0                29200         2012-01-03
# 1                29200         2012-01-04
# 2                29200         2012-01-05
# 3                29600         2012-01-06
# 4                31200         2012-01-07

# %%
# ubah nama kolom jadi Y dan DS
df.columns=['y','ds']
df.head()
# Out:
#        y          ds
# 0  29200  2012-01-03
# 1  29200  2012-01-04
# 2  29200  2012-01-05
# 3  29600  2012-01-06
# 4  31200  2012-01-07

# %%
#start year 2011
#start_date = "2011-01-01"
#df = df.loc[df.ds > start_date].copy()

# %%
# Split data training dan testing
split_date = "2019-01-01"
df_train = df.loc[df.ds <= split_date].copy() 
df_test = df.loc[df.ds > split_date].copy()
df_train.tail()
# Out:
#           y          ds
# 1644  36400  2018-12-18
# 1645  36400  2018-12-19
# 1646  36400  2018-12-20
# 1647  61000  2018-12-27
# 1648  65000  2018-12-28

# %%
df_test.head()
# Out:
#           y          ds
# 1649  62000  2019-01-02
# 1650  65500  2019-01-04
# 1651  48000  2019-01-07
# 1652  43667  2019-01-08
# 1653  40333  2019-01-10

# %%
# fitting model
m = Prophet()
m.add_country_holidays(country_name = 'ID')
m.fit(df_train)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# C:\Users\azra\anaconda3\lib\site-packages\fbprophet\hdays.py:105: Warning: We only support Nyepi holiday from 2009 to 2019
#   warnings.warn(warning_msg, Warning)

# %%
# bikin prediksi dari model yang udah dibuat
forecast = m.predict(df_test)
forecast.tail()
# Out:
# C:\Users\azra\anaconda3\lib\site-packages\fbprophet\hdays.py:105: Warning: We only support Nyepi holiday from 2009 to 2019
#   warnings.warn(warning_msg, Warning)
# C:\Users\azra\anaconda3\lib\site-packages\fbprophet\hdays.py:105: Warning: We only support Nyepi holiday from 2009 to 2019
#   warnings.warn(warning_msg, Warning)
#             ds        trend   yhat_lower    yhat_upper  trend_lower  \
# 192 2020-03-02  7451.939623 -2964.696852  46384.380138 -1536.156036
# 193 2020-03-03  7396.160734 -3521.303288  49027.598427 -1625.255996
# 194 2020-03-04  7340.381845 -1357.138388  48613.280421 -1716.180886
# 195 2020-03-05  7284.602955 -2436.765537  48553.056650 -1802.367725
# 196 2020-03-08  7117.266288 -3536.273082  46456.691071 -2080.404583
#
#       trend_upper  Ascension of Jesus  Ascension of Jesus_lower  \
# 192  14909.937931                 0.0                       0.0
# 193  14874.223128                 0.0                       0.0
# 194  14840.316952                 0.0                       0.0
# 195  14817.790390                 0.0                       0.0
# 196  14732.711454                 0.0                       0.0
#
#      Ascension of Jesus_upper  Ascension of the Prophet  ...       weekly  \
# 192                       0.0                       0.0  ...   578.173483
# 193                       0.0                       0.0  ...   711.531522
# 194                       0.0                       0.0  ...   689.515436
# 195                       0.0                       0.0  ...   838.668973
# 196                       0.0                       0.0  ... -3165.366638
#
#      weekly_lower  weekly_upper        yearly  yearly_lower  yearly_upper  \
# 192    578.173483    578.173483  14907.850553  14907.850553  14907.850553
# 193    711.531522    711.531522  15641.616437  15641.616437  15641.616437
# 194    689.515436    689.515436  16354.562777  16354.562777  16354.562777
# 195    838.668973    838.668973  17036.869432  17036.869432  17036.869432
# 196  -3165.366638  -3165.366638  18809.746030  18809.746030  18809.746030
#
#      multiplicative_terms  multiplicative_terms_lower  \
# 192                   0.0                         0.0
# 193                   0.0                         0.0
# 194                   0.0                         0.0
# 195                   0.0                         0.0
# 196                   0.0                         0.0
#
#      multiplicative_terms_upper          yhat
# 192                         0.0  22937.963658
# 193                         0.0  23749.308693
# 194                         0.0  24384.460057
# 195                         0.0  25160.141360
# 196                         0.0  22761.645680
#
# [5 rows x 64 columns]

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)
# Out:
# C:\Users\azra\anaconda3\lib\site-packages\fbprophet\hdays.py:105: Warning: We only support Nyepi holiday from 2009 to 2019
#   warnings.warn(warning_msg, Warning)
# C:\Users\azra\anaconda3\lib\site-packages\fbprophet\hdays.py:105: Warning: We only support Nyepi holiday from 2009 to 2019
#   warnings.warn(warning_msg, Warning)

# %%
mse = mean_squared_error(y_true = df_test["y"], y_pred = forecast['yhat'])
mse
# Out:
# 1755219089.5961473

# %%
mae = mean_absolute_error(y_true = df_test["y"], y_pred = forecast['yhat'])
mae
# Out:
# 34850.65180015591

# %%
def mean_abs_perc_err(y_true, y_pred) :
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape = mean_abs_perc_err(y_true = np.asarray(df_test["y"]), y_pred = np.asarray(forecast['yhat']))
mape
# Out:
# 61.0801538716809

# %%
akurasi = 100 - mape
akurasi
# Out:
# 38.9198461283191
