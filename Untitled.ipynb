# %%
# import semua lib yang diperlukan
import pandas as pd
import numpy as np
from fbprophet import Prophet
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('dataset/bawang merah.csv')
df
# Out:
#      status  message  data__total  data__result__value data__result__time  \
# 0        ok      NaN   54438070.0                 9750    January 3, 2009
# 1       NaN      NaN          NaN                 9750    January 4, 2009
# 2       NaN      NaN          NaN                 9750    January 5, 2009
# 3       NaN      NaN          NaN                 9750    January 6, 2009
# 4       NaN      NaN          NaN                 9750    January 7, 2009
# ...     ...      ...          ...                  ...                ...
# 2220    NaN      NaN          NaN                32600      March 2, 2020
# 2221    NaN      NaN          NaN                32600      March 3, 2020
# 2222    NaN      NaN          NaN                32600      March 4, 2020
# 2223    NaN      NaN          NaN                35000      March 5, 2020
# 2224    NaN      NaN          NaN                32400      March 8, 2020
#
#      data__result__date  data__result__span  data__average  data__location_id  \
# 0            2009-01-03                   3        24467.0                1.0
# 1            2009-01-04                   4            NaN                NaN
# 2            2009-01-05                   5            NaN                NaN
# 3            2009-01-06                   6            NaN                NaN
# 4            2009-01-07                   7            NaN                NaN
# ...                 ...                 ...            ...                ...
# 2220         2020-03-02                  62            NaN                NaN
# 2221         2020-03-03                  63            NaN                NaN
# 2222         2020-03-04                  64            NaN                NaN
# 2223         2020-03-05                  65            NaN                NaN
# 2224         2020-03-08                  68            NaN                NaN
#
#       data__commodity_id        data__legend data__commodity_name  \
# 0                    3.0  Harga Kota Bandung         Bawang Merah
# 1                    NaN                 NaN                  NaN
# 2                    NaN                 NaN                  NaN
# 3                    NaN                 NaN                  NaN
# 4                    NaN                 NaN                  NaN
# ...                  ...                 ...                  ...
# 2220                 NaN                 NaN                  NaN
# 2221                 NaN                 NaN                  NaN
# 2222                 NaN                 NaN                  NaN
# 2223                 NaN                 NaN                  NaN
# 2224                 NaN                 NaN                  NaN
#
#               stat__|  stat__|__total  stat__|__nb_data  stat__|__avg
# 0     January 3, 2009            9750                 1          9750
# 1     January 4, 2009            9750                 1          9750
# 2     January 5, 2009            9750                 1          9750
# 3     January 6, 2009            9750                 1          9750
# 4     January 7, 2009            9750                 1          9750
# ...               ...             ...               ...           ...
# 2220    March 2, 2020           32600                 1         32600
# 2221    March 3, 2020           32600                 1         32600
# 2222    March 4, 2020           32600                 1         32600
# 2223    March 5, 2020           35000                 1         35000
# 2224    March 8, 2020           32400                 1         32400
#
# [2225 rows x 16 columns]

# %%
#data cleaning(hapus data yang tidak terpakai)
df.drop(['status','message','data__total','data__result__time','data__result__span','data__average','data__location_id','data__commodity_id','data__legend','data__commodity_name','stat__|','stat__|__total','stat__|__nb_data','stat__|__avg'], axis=1, inplace=True)
df.head()
# Out:
#    data__result__value data__result__date
# 0                 9750         2009-01-03
# 1                 9750         2009-01-04
# 2                 9750         2009-01-05
# 3                 9750         2009-01-06
# 4                 9750         2009-01-07

# %%
# ubah nama kolom jadi Y dan DS
df.columns=['y','ds']
df.head()
# Out:
#       y          ds
# 0  9750  2009-01-03
# 1  9750  2009-01-04
# 2  9750  2009-01-05
# 3  9750  2009-01-06
# 4  9750  2009-01-07

# %%
df = df.loc[df.y > 0].copy()
df = df.dropna()
df
# Out:
#           y          ds
# 0      9750  2009-01-03
# 1      9750  2009-01-04
# 2      9750  2009-01-05
# 3      9750  2009-01-06
# 4      9750  2009-01-07
# ...     ...         ...
# 2220  32600  2020-03-02
# 2221  32600  2020-03-03
# 2222  32600  2020-03-04
# 2223  35000  2020-03-05
# 2224  32400  2020-03-08
#
# [2222 rows x 2 columns]

# %%
df['ds'] = pd.to_datetime(df['ds'])
df = df.set_index('ds').asfreq('D')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-7182cd1e4561> in <module>
# ----> 1 df['ds'] = pd.to_datetime(df['ds'])
#       2 df = df.set_index('ds').asfreq('D')
#       3 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'ds'

# %%
result = seasonal_decompose(df['y'], model = 'additive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-1d2d2b65cefa> in <module>
# ----> 1 result = seasonal_decompose(df['y'], model = 'additive')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     129
#     130     if not np.all(np.isfinite(x)):
# --> 131         raise ValueError("This function does not handle missing values")
#     132     if model.startswith('m'):
#     133         if np.any(x <= 0):
#
# ValueError: This function does not handle missing values
